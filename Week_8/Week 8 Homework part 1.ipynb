# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import datetime
import seaborn as sns
# %matplotlib inline

# %%
def fix_nan(data):
    try:
        data = str(data)
        return datetime.datetime.strptime(data,'%m/%d/%Y %I:%M:%S %p')
    except:
        return np.NaN

# %%
df = pd.read_csv("311_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Unique Key            Created Date             Closed Date  \
# 0           0    32305299  01/01/2016 12:00:09 AM  01/01/2016 01:57:32 AM
# 1           1    32310343  01/01/2016 12:00:40 AM  01/01/2016 03:12:53 AM
# 2           2    32309107  01/01/2016 12:01:09 AM  01/21/2016 09:20:55 AM
# 3           3    32308578  01/01/2016 12:02:59 AM  01/01/2016 11:35:50 PM
# 4           4    32309212  01/01/2016 12:03:03 AM  01/08/2016 01:13:00 AM
#
#   Agency                                        Agency Name  \
# 0   NYPD                    New York City Police Department
# 1   NYPD                    New York City Police Department
# 2    HPD  Department of Housing Preservation and Develop...
# 3   NYPD                    New York City Police Department
# 4    HPD  Department of Housing Preservation and Develop...
#
#             Complaint Type        Descriptor               Location Type  \
# 0  Noise - Street/Sidewalk  Loud Music/Party             Street/Sidewalk
# ...

# %%
df['Created Date'] = df['Created Date'].apply(lambda x:datetime.datetime.strptime(x,'%m-%d-%Y %I:%M:%S'))
df["Closed Date"] = df["Closed Date"].apply(fix_nan)
df["processing_time"] = df["Closed Date"] - df["Created Date"]
df["start_time_window"] = df["Created Date"].apply(lambda x:x.hour)
lst = ["Closed Date", "Created Date", "Agency", "Borough", "processing_time", "start_time_window"]
df[lst].to_csv("output1.csv" )

# %%
df["Created Date"]
# Out:
# 0      2016-01-01 00:00:09
# 1      2016-01-01 00:00:40
# 2      2016-01-01 00:01:09
# 3      2016-01-01 00:02:59
# 4      2016-01-01 00:03:03
# 5      2016-01-01 00:03:03
# 6      2016-01-01 00:03:29
# 7      2016-01-01 00:04:06
# 8      2016-01-01 00:04:37
# 9      2016-01-01 00:04:56
# 10     2016-01-01 00:05:04
# 11     2016-01-01 00:05:09
# 12     2016-01-01 00:05:19
# 13     2016-01-01 00:05:35
# 14     2016-01-01 00:06:32
# 15     2016-01-01 00:07:32
# 16     2016-01-01 00:07:51
# 17     2016-01-01 00:08:07
# 18     2016-01-01 00:08:14
# 19     2016-01-01 00:08:30
# 20     2016-01-01 00:08:35
# 21     2016-01-01 00:09:58
# 22     2016-01-01 00:09:58
# 23     2016-01-01 00:10:02
# 24     2016-01-01 00:10:06
# 25     2016-01-01 00:10:11
# 26     2016-01-01 00:10:12
# 27     2016-01-01 00:10:19
# 28     2016-01-01 00:11:25
# 29     2016-01-01 00:11:42
#                ...
# 1497   2016-01-01 08:45:00
# 1498   2016-01-01 08:46:00
# 1499   2016-01-01 08:46:00
# ...

# %%
start_time_window.size().plot(kind="bar")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-320e074dfd5f> in <module>()
# ----> 1 start_time_window.size().plot(kind="bar")
#
# NameError: name 'start_time_window' is not defined
